# %%
#1. Data Processing
#Importing all the nesessary Libraries

# 1. Core Data Manipulation
import pandas as pd
from pathlib import Path
# 2. Pre-processing & Machine Learning
from sklearn.preprocessing import MinMaxScaler, StandardScaler # For scaling your data
from sklearn.impute import KNNImputer                          # For advanced missing data filling

# 3. Visualization (To verify your cleaning)
import matplotlib.pyplot as plt  # For plotting trends
import seaborn as sns            # For heatmaps and outlier boxplots

# %%
#Data Consolidation Pipeline
#The code looks into your folder and finds all your CSV files and transforms individual data to clean unified database

# %%
import pandas as pd
from pathlib import Path


path = Path("Data19to23")
# Combines your folder name and the *.csv pattern into a list of CSV files.
all_files = sorted(path.glob("*.csv"))

## li-- Initializes an empty list to hold the data from each file temporarily.
li = []

# This code transforms a messy folder of individual reports into a clean, unified database.
for filename in all_files:
    df = pd.read_csv(filename, sep=";", index_col=None, header=0)
    df['Patient_ID'] = filename.stem
    li.append(df)
    
#Merging everything
combined_activity = pd.concat(li, axis=0, ignore_index=True)
combined_activity.to_csv("Combined_Datasets_19to23.csv", index=False)

# %%
df.head(6)
# Out:
#                   time    glucose  calories  heart_rate  steps  basal_rate  \
# 0  2020-01-17T00:00:00  40.000000   15.0429   96.371901    8.0       0.035
# 1  2020-01-17T00:05:00  41.333333    8.3164   91.395349    0.0       0.035
# 2  2020-01-17T00:10:00  42.666667    7.5826   85.991935    0.0       0.035
# 3  2020-01-17T00:15:00  44.000000    7.3380   82.434426    0.0       0.035
# 4  2020-01-17T00:20:00  50.000000    7.5826   78.822581    0.0       0.035
# 5  2020-01-17T00:25:00  56.000000    7.5826   81.101562    0.0       0.035
#
#    bolus_volume_delivered  carb_input Patient_ID
# 0                     0.0         1.0  HUPA0023P
# 1                     0.0         0.0  HUPA0023P
# 2                     0.0         0.0  HUPA0023P
# 3                     0.0         0.0  HUPA0023P
# 4                     0.0         0.0  HUPA0023P
# 5                     0.0         0.0  HUPA0023P

# %%
df.shape
# Out:
# (3919, 9)

# %%
#Change time data type to datetime

# %%
df['time'] = pd.to_datetime(df['time'])
df
# Out:
#                     time  glucose  calories  heart_rate  steps  basal_rate  \
# 0    2020-01-17 00:00:00   40.000    15.043      96.372    8.0       0.035
# 1    2020-01-17 00:05:00   41.333     8.316      91.395    0.0       0.035
# 2    2020-01-17 00:10:00   42.667     7.583      85.992    0.0       0.035
# 3    2020-01-17 00:15:00   44.000     7.338      82.434    0.0       0.035
# 4    2020-01-17 00:20:00   50.000     7.583      78.823    0.0       0.035
# ...                  ...      ...       ...         ...    ...         ...
# 3914 2020-01-30 14:10:00   76.000     6.727      67.932    0.0       0.035
# 3915 2020-01-30 14:15:00   76.000    12.841      69.116   39.0       0.035
# 3916 2020-01-30 14:20:00   76.333     6.604      63.786    0.0       0.035
# 3917 2020-01-30 14:25:00   76.667     6.849      69.115    0.0       0.035
# 3918 2020-01-30 14:30:00   77.000    12.964      71.150   20.0       0.035
#
#       bolus_volume_delivered  carb_input Patient_ID  hour
# 0                        0.0         1.0  HUPA0023P     0
# 1                        0.0         0.0  HUPA0023P     0
# 2                        0.0         0.0  HUPA0023P     0
# 3                        0.0         0.0  HUPA0023P     0
# 4                        0.0         0.0  HUPA0023P     0
# ...                      ...         ...        ...   ...
# 3914                     0.0         0.0  HUPA0023P    14
# 3915                     0.0         0.0  HUPA0023P    14
# 3916                     0.0         0.0  HUPA0023P    14
# 3917                     0.0         0.0  HUPA0023P    14
# 3918                     0.0         0.0  HUPA0023P    14
#
# [3919 rows x 10 columns]

# %%
#Rounding the columns to 3 decimals

# %%
cols_to_round = ["glucose", "calories", "heart_rate"]

df[cols_to_round] = df[cols_to_round].round(3)

# %%
df.dtypes
# Out:
# time                       object
# glucose                   float64
# calories                  float64
# heart_rate                float64
# steps                     float64
# basal_rate                float64
# bolus_volume_delivered    float64
# carb_input                float64
# Patient_ID                 object
# dtype: object

# %%
#Standardizing Time zones If some data was recorded in UTC and some in EST, 
#it strips those labels so they can be compared easily as "naive" local
#time and sort time zones in chronlogical order removing duplicates

# %%
# Convert to datetime and strip timezone info
df['time'] = pd.to_datetime(df['time']).dt.tz_localize(None)

# Sort and remove duplicates (keep the first occurrence)
df = df.sort_values(['Patient_ID', 'time'])
df = df.drop_duplicates(subset=['Patient_ID', 'time'], keep='first').reset_index(drop=True)

# %%
df.head()
# Out:
#                   time    glucose  calories  heart_rate  steps  basal_rate  \
# 0  2020-01-17T00:00:00  40.000000   15.0429   96.371901    8.0       0.035
# 1  2020-01-17T00:05:00  41.333333    8.3164   91.395349    0.0       0.035
# 2  2020-01-17T00:10:00  42.666667    7.5826   85.991935    0.0       0.035
# 3  2020-01-17T00:15:00  44.000000    7.3380   82.434426    0.0       0.035
# 4  2020-01-17T00:20:00  50.000000    7.5826   78.822581    0.0       0.035
#
#    bolus_volume_delivered  carb_input Patient_ID
# 0                     0.0         1.0  HUPA0023P
# 1                     0.0         0.0  HUPA0023P
# 2                     0.0         0.0  HUPA0023P
# 3                     0.0         0.0  HUPA0023P
# 4                     0.0         0.0  HUPA0023P

# %%
#Checking for Outliers

# %%
numeric_cols = [
    'glucose',
    'calories',
    'heart_rate',
    'steps',
    'basal_rate',
    'bolus_volume_delivered',
    'carb_input'
]

# Compute IQR
Q1 = df[numeric_cols].quantile(0.25)
Q3 = df[numeric_cols].quantile(0.75)
IQR = Q3 - Q1

# Outlier mask (DataFrame of True/False)
outliers = (df[numeric_cols] < (Q1 - 1.5 * IQR)) | \
           (df[numeric_cols] > (Q3 + 1.5 * IQR))

# Count outliers per column
outliers.sum()
# Out:
# glucose                    12
# calories                  396
# heart_rate                 51
# steps                     851
# basal_rate                384
# bolus_volume_delivered     40
# carb_input                 63
# dtype: int64

# %%
df.head(3)
# Out:
#                   time    glucose  calories  heart_rate  steps  basal_rate  \
# 0  2020-01-17T00:00:00  40.000000   15.0429   96.371901    8.0       0.035
# 1  2020-01-17T00:05:00  41.333333    8.3164   91.395349    0.0       0.035
# 2  2020-01-17T00:10:00  42.666667    7.5826   85.991935    0.0       0.035
#
#    bolus_volume_delivered  carb_input Patient_ID
# 0                     0.0         1.0  HUPA0023P
# 1                     0.0         0.0  HUPA0023P
# 2                     0.0         0.0  HUPA0023P

# %%
df.tail(7)
# Out:
#                       time     glucose  calories  heart_rate  steps  \
# 25895  2022-05-18T11:45:00  100.000000   5.75616   91.121495    0.0
# 25896  2022-05-18T11:50:00  104.666667   8.54430   99.737705    0.0
# 25897  2022-05-18T11:55:00  109.333333  10.79280  104.171171    0.0
# 25898  2022-05-18T12:00:00  114.000000   9.80346  103.442623    0.0
# 25899  2022-05-18T12:05:00  118.666667   5.66622   95.542857    0.0
# 25900  2022-05-18T12:10:00  123.333333   5.57628   91.381356    0.0
# 25901  2022-05-18T12:15:00  128.000000   5.57628   99.257812    0.0
#
#        basal_rate  bolus_volume_delivered  carb_input Patient_ID
# 25895         0.0                     0.0         0.0  HUPA0028P
# 25896         0.0                     0.0         0.0  HUPA0028P
# 25897         0.0                     0.0         0.0  HUPA0028P
# 25898         0.0                     0.0         0.0  HUPA0028P
# 25899         0.0                     0.0         0.0  HUPA0028P
# 25900         0.0                     0.0         0.0  HUPA0028P
# 25901         0.0                     0.0         0.0  HUPA0028P
