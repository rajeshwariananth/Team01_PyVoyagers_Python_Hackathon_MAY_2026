# %% [markdown]
# <h1 align="center">Data Cleaning</h1>

# %% [markdown]
# ## Importing all the nesessary Libraries

# %%
# 1. Core Data Manipulation
import pandas as pd              # For DataFrames and CSV handling
import numpy as np               # For mathematical operations and handling NaN
from pathlib import Path        # For modern, clean file path handling

# 2. Pre-processing & Machine Learning
from sklearn.preprocessing import MinMaxScaler, StandardScaler # For scaling your data
from sklearn.impute import KNNImputer                          # For advanced missing data filling

# 3. Visualization (To verify your cleaning)
import matplotlib.pyplot as plt  # For plotting trends
import seaborn as sns # For heatmaps and outlier boxplots
import warnings
warnings.simplefilter("ignore", UserWarning)

# %% [markdown]
# # Data Consolidation Pipeline
# The code looks into your folder and finds all your CSV files and transforms individual data to clean unified database

# %%
import pandas as pd
from pathlib import Path

path = Path("data/raw/1-28Patients")
# Combines your folder name and the *.csv pattern into a list of CSV files.
all_files = sorted(path.glob("*.csv"))

#The loop (processing each file)
## li-- Initializes an empty list to hold the data from each file temporarily.
li =[]

# This code transforms a messy folder of individual reports into a clean, unified database.
for filename in all_files:
    df = pd.read_csv(filename, sep=";", index_col = None, header=0)
    #Tagging the Data 
    df['patient_id'] = filename.stem
    li.append(df)

#Merging everything

combined_activity = pd.concat(li, axis= 0,ignore_index = True)
#combined_activity.to_csv("Combined_Datasets_1-28.csv", index=False)
combined_activity.to_csv("data/raw/Combined_Datasets_1-28.csv", index=False)

# %%
df=combined_activity
df.shape
# Out:
# (309392, 9)

# %% [markdown]
# # Checking for Outliers
# Outlier detection ensures that our descriptive statistics accurately reflect the majority of the populationand prevents extreme, erronous or rare valus from biasing our predective models and statistical conclusions

# %%
numeric_cols = [
    'glucose',
    'calories',
    'heart_rate',
    'steps',
    'basal_rate'


]
 # Q1 is value where 25% of data falls Q3 is value where 75% of data falls. IQR gived the 50% data range ,this is the most reliable part of your dataset because it ignores the extreme highs and extreme lows.
Q1 = df[numeric_cols].quantile(0.25)
Q3 = df[numeric_cols].quantile(0.75)
IQR = Q3 - Q1

outliers = (
    df[numeric_cols] < (Q1 - 1.5 * IQR)
) | (
    df[numeric_cols] > (Q3 + 1.5 * IQR)
)

outliers.sum()
# Out:
# glucose        6897
# calories      46725
# heart_rate     6393
# steps         60387
# basal_rate      672
# dtype: int64

# %% [markdown]
# ## Replacing Outliers

# %% [markdown]
# Using the 1.5×IQR rule to detect outliers and cap them to safe limits, ensuring your numeric clinical data stays clean, stable, and analysis‑ready without losing any rows.

# %%
# 1. Define your fences upper and lower bounds 
lower_fence = Q1 - 1.5 * IQR
upper_fence = Q3 + 1.5 * IQR

# 2. Apply the cap (clipping i.e is easier way of handling if/else logic for many rows at once)
df_cleaned = df.copy()
# 3. Replacing lower outliers with lower fence and upper detected outlier with upper fence value
df_cleaned[numeric_cols] = df_cleaned[numeric_cols].clip(lower=lower_fence, upper=upper_fence, axis=1)

print("Outliers have been capped to the 1.5*IQR fences.")
# Out:
# Outliers have been capped to the 1.5*IQR fences.

# %% [markdown]
# ## Change 'time' data type to datetime
# Converting the 'time' column to a Datetime object transforms static text into a dynamic temporal variable. This enables chronological sorting, time-based arithmetic, and the ability to extract seasonal or hourly patterns essential for time-series analysis.

# %%
df_cleaned['time']=pd.to_datetime(df_cleaned['time'])

# %%
df_cleaned.dtypes
# Out:
# time                      datetime64[ns]
# glucose                          float64
# calories                         float64
# heart_rate                       float64
# steps                            float64
# basal_rate                       float64
# bolus_volume_delivered           float64
# carb_input                       float64
# patient_id                        object
# dtype: object

# %% [markdown]
# ## Standardizing Time zones
# If some data was recorded in UTC and some in EST, it strips those labels so they can be compared easily as "naive" local time and sort time zones in chronlogical order removing duplicates. It ensures time series analysis is accurate and comparable

# %%
# 1. Convert to datetime and strip timezone info
df_cleaned['time'] = pd.to_datetime(df_cleaned['time']).dt.tz_localize(None)

# 2. Sort using df_cleaned
df_cleaned = df_cleaned.sort_values(['patient_id','time'])

# 3. Drop duplicates using df_cleaned
df_cleaned = df_cleaned.drop_duplicates(subset=['patient_id','time'], keep='first').reset_index(drop=True)
print(df_cleaned.duplicated(subset=['patient_id','time']).sum())

# %% [markdown]
# df is original and df_cleaned is the result

# %%
print(f"Count before cleaning: {df.shape[0]}")
print(f"Count after cleaning:  {df_cleaned.shape[0]}") # indicates no dupliactes

# %%
df_cleaned.shape

# %% [markdown]
# # Visualization for Outliers Validation
# The visualization confirms that outlier handling was successful by showing a cleaner, more stable distribution. It verifies that extreme anomalies have been removed, most values now fall within expected statistical ranges, and the relative spread of each variable is consistent. Any remaining isolated points likely represent meaningful natural variation rather than data errors.

# %%
plt.figure(figsize=(12, 6))
# Plotting the main variables to see if they stay within the whiskers
sns.boxplot(data=df_cleaned[numeric_cols])
plt.title("Distribution Check: Verifying Outlier Removal")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Data Comparison before and after Outliers

# %%
# Data comparison before and after cleaning
print("Patients steps before cleaning :", df['steps'].max())
print("Patients steps after cleaning :", df_cleaned['steps'].max())

# %% [markdown]
# ## Missing data Audit
# This heatmap provides a quick visual audit of missing values. Since the plot appears fully purple, it confirms that all records are complete and no missing data remains after cleaning.”

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title("Missing Data Audit: Purple means Clean")
plt.show()

# %% [markdown]
# ## Cleaned DataFrame to a CSV file and shows a sample of the cleaned records to confirm that all transformations were applied correctly.

# %%
df_cleaned.to_csv("data/cleaned/cleaned_data.csv",index=False)

# %%
df_cleaned.shape

# %% [markdown]
# ## Adding Demographics table to df_demographics data frame

# %%
df_demographics=pd.read_csv("data/raw/T1DM_patient_sleep_demographics_with_race.csv")

# %%
df_demographics

# %% [markdown]
# ## Standardizing column names and converting to snake_case form

# %%
df_demographics.columns = (
    df_demographics.columns
      .str.strip()                     # remove leading/trailing spaces
      .str.lower()                     # convert to lowercase
      .str.replace(' ', '_')           # replace spaces with underscores
      .str.replace('-', '_')           # replace hyphens with underscores
      .str.replace(r'[^a-z0-9_]', '', regex=True)  # remove special chars
)

# %%
df_cleaneddemo=df_demographics.to_csv("data/cleaned/Cleaned_demographics.csv",index=False)

# %% [markdown]
# ## Merging demographics table to cleaned csv using left join

# %%
df_final=df_cleaned.merge(df_demographics,on="patient_id", how="left")

# %%
df_final

# %% [markdown]
# # Rounding the columns to 3 decimals
# Rounding to 3 decimal places standardizes the precision across features, removed floating point and ensures the data remainsinterpretable for statistical reporting while maintaining necessary level of clinical detail.

# %%
cols=['calories','glucose','heart_rate','steps','basal_rate']
df_final[cols]=df_final[cols].round(3)
df_final.head()
df_final.shape

# %% [markdown]
# ## Converting the combined demographics and cleaned data as csv file

# %%
df_final.to_csv("data/cleaned/Team01_PYVoyagers_cleaned_data.csv",index=False)
